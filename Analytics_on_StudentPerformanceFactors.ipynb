# %% [markdown]
# # Data analysis on student data

# %% [markdown]
# ## Import the required libraries

# %%
# Import Pandas
import pandas as pd

# Import numpy
import numpy as np

# Import matplotlib
import matplotlib.pyplot as plt

# Import seaborn
import seaborn as sns

# %% [markdown]
# ### Load The Data Set

# %%
# Read the data file we have in the folder
df_student = pd.read_csv('StudentPerformanceFactors.csv')

df_student
# Out:
#         Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                  23          84                  Low                High
# 1                  19          64                  Low              Medium
# 2                  24          98               Medium              Medium
# 3                  29          89                  Low              Medium
# 4                  19          92               Medium              Medium
# ...               ...         ...                  ...                 ...
# 124689             29          97               Medium                High
# 124690             26          75                 High              Medium
# 124691             24          62               Medium              Medium
# 124692             30         100                  Low              Medium
# 124693             11          72                 High              Medium
#
#        Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# #### Data Overview

# %%
# Show First 5 observations of data
df_student.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
# Show Last 5 observations of data
df_student.tail()
# Out:
#         Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 124689             29          97               Medium                High
# 124690             26          75                 High              Medium
# 124691             24          62               Medium              Medium
# 124692             30         100                  Low              Medium
# 124693             11          72                 High              Medium
#
#        Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 124689                         No           10               97
# 124690                         No            6               76
# 124691                        Yes           10               65
# 124692                         No            8               50
# 124693                         No            8               70
#
#        Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# ...

# %%
# Show the shape of the data
df_student.shape
# Out:
# (124694, 20)

# %% [markdown]
# ***Interpretation***
#  - We have 124694 observations(rows)
#  - We have 20 attributes(columns)

# %%
# Show the basic info of the data
df_student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124694 entries, 0 to 124693
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Hours_Studied               124694 non-null  int64
#  1   Attendance                  124694 non-null  int64
#  2   Parental_Involvement        124694 non-null  object
#  3   Access_to_Resources         124694 non-null  object
#  4   Extracurricular_Activities  124694 non-null  object
#  5   Sleep_Hours                 124694 non-null  int64
#  6   Previous_Scores             124694 non-null  int64
#  7   Motivation_Level            124694 non-null  object
#  8   Internet_Access             124694 non-null  object
#  9   Tutoring_Sessions           124694 non-null  int64
#  10  Family_Income               124694 non-null  object
#  11  Teacher_Quality             123322 non-null  object
#  12  School_Type                 124694 non-null  object
# ...

# %% [markdown]
# ***Interpretation***
#  - We have 7 numerical column and 13 categorical column
#  - Memory usage if 19.0+ mb that means we does not required extra resources
#  - After observing output we can say missing records are there in data

# %%
df_student.describe()
# Out:
#        Hours_Studied     Attendance    Sleep_Hours  Previous_Scores  \
# count  124694.000000  124694.000000  124694.000000    124694.000000
# mean       19.963094      79.964890       7.022407        75.061511
# std         6.285341      11.624999       2.051355        14.449634
# min         1.000000      60.000000       4.000000        50.000000
# 25%        16.000000      70.000000       5.000000        63.000000
# 50%        20.000000      80.000000       7.000000        75.000000
# 75%        24.000000      90.000000       9.000000        88.000000
# max        44.000000     100.000000      10.000000       100.000000
#
#        Tutoring_Sessions  Physical_Activity     Exam_Score
# count      124694.000000      124694.000000  124694.000000
# mean            1.841909           2.965171      67.228792
# std             1.846378           1.983697       4.381052
# min             0.000000           0.000000      55.000000
# ...

# %%
# Justify the baisc statistics of the data
df_student.describe().T
# Out:
#                       count       mean        std   min   25%   50%   75%  \
# Hours_Studied      124694.0  19.963094   6.285341   1.0  16.0  20.0  24.0
# Attendance         124694.0  79.964890  11.624999  60.0  70.0  80.0  90.0
# Sleep_Hours        124694.0   7.022407   2.051355   4.0   5.0   7.0   9.0
# Previous_Scores    124694.0  75.061511  14.449634  50.0  63.0  75.0  88.0
# Tutoring_Sessions  124694.0   1.841909   1.846378   0.0   0.0   1.0   3.0
# Physical_Activity  124694.0   2.965171   1.983697   0.0   1.0   3.0   5.0
# Exam_Score         124694.0  67.228792   4.381052  55.0  64.0  67.0  70.0
#
#                      max
# Hours_Studied       44.0
# Attendance         100.0
# Sleep_Hours         10.0
# Previous_Scores    100.0
# Tutoring_Sessions    8.0
# Physical_Activity    6.0
# Exam_Score         101.0

# %% [markdown]
# ***Interpretation***
#  - we dont have outliars in the data

# %% [markdown]
# ## Data Preprocessing

# %%
# null value handling
df_student.isnull()
# Out:
#         Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0               False       False                 False                False
# 1               False       False                 False                False
# 2               False       False                 False                False
# 3               False       False                 False                False
# 4               False       False                 False                False
# ...               ...         ...                   ...                  ...
# 124689          False       False                 False                False
# 124690          False       False                 False                False
# 124691          False       False                 False                False
# 124692          False       False                 False                False
# 124693          False       False                 False                False
#
# ...

# %%
# Show the count of null record in the data
df_student.isnull().sum()
# Out:
# Hours_Studied                    0
# Attendance                       0
# Parental_Involvement             0
# Access_to_Resources              0
# Extracurricular_Activities       0
# Sleep_Hours                      0
# Previous_Scores                  0
# Motivation_Level                 0
# Internet_Access                  0
# Tutoring_Sessions                0
# Family_Income                    0
# Teacher_Quality               1372
# School_Type                      0
# Peer_Influence                   0
# Physical_Activity                0
# Learning_Disabilities            0
# Parental_Education_Level      1720
# Distance_from_Home            1281
# Gender                           0
# Exam_Score                       0
# dtype: int64

# %%
# Find the percentage of missing records
df_student.isnull().sum()/len(df_student)*100
# Out:
# Hours_Studied                 0.000000
# Attendance                    0.000000
# Parental_Involvement          0.000000
# Access_to_Resources           0.000000
# Extracurricular_Activities    0.000000
# Sleep_Hours                   0.000000
# Previous_Scores               0.000000
# Motivation_Level              0.000000
# Internet_Access               0.000000
# Tutoring_Sessions             0.000000
# Family_Income                 0.000000
# Teacher_Quality               1.100294
# School_Type                   0.000000
# Peer_Influence                0.000000
# Physical_Activity             0.000000
# Learning_Disabilities         0.000000
# Parental_Education_Level      1.379377
# Distance_from_Home            1.027315
# Gender                        0.000000
# Exam_Score                    0.000000
# dtype: float64

# %%
df_student.dropna(inplace = True)

# %%
df_student.isnull().sum()/len(df_student)*100
# Out:
# Hours_Studied                 0.0
# Attendance                    0.0
# Parental_Involvement          0.0
# Access_to_Resources           0.0
# Extracurricular_Activities    0.0
# Sleep_Hours                   0.0
# Previous_Scores               0.0
# Motivation_Level              0.0
# Internet_Access               0.0
# Tutoring_Sessions             0.0
# Family_Income                 0.0
# Teacher_Quality               0.0
# School_Type                   0.0
# Peer_Influence                0.0
# Physical_Activity             0.0
# Learning_Disabilities         0.0
# Parental_Education_Level      0.0
# Distance_from_Home            0.0
# Gender                        0.0
# Exam_Score                    0.0
# dtype: float64

# %%
df_student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120425 entries, 0 to 124693
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Hours_Studied               120425 non-null  int64
#  1   Attendance                  120425 non-null  int64
#  2   Parental_Involvement        120425 non-null  object
#  3   Access_to_Resources         120425 non-null  object
#  4   Extracurricular_Activities  120425 non-null  object
#  5   Sleep_Hours                 120425 non-null  int64
#  6   Previous_Scores             120425 non-null  int64
#  7   Motivation_Level            120425 non-null  object
#  8   Internet_Access             120425 non-null  object
#  9   Tutoring_Sessions           120425 non-null  int64
#  10  Family_Income               120425 non-null  object
#  11  Teacher_Quality             120425 non-null  object
#  12  School_Type                 120425 non-null  object
# ...

# %%
df_student.shape
# Out:
# (120425, 20)

# %%
df_student.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %% [markdown]
# # **UNIVARIATE ANALYSIS**

# %%
# Segregate Data based on Data type

df_num = df_student.select_dtypes(include = "number")

df_cat = df_student.select_dtypes(include = "object")

# %%
# Show the Numerical data

df_num.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  \
# 0             23          84            7               73                  0
# 1             19          64            8               59                  2
# 2             24          98            7               91                  2
# 3             29          89            8               98                  1
# 4             19          92            6               65                  3
#
#    Physical_Activity  Exam_Score
# 0                  3          67
# 1                  4          61
# 2                  4          74
# 3                  4          71
# 4                  4          70

# %%
# Show the Categorical data
df_cat.head()
# Out:
#   Parental_Involvement Access_to_Resources Extracurricular_Activities  \
# 0                  Low                High                         No
# 1                  Low              Medium                         No
# 2               Medium              Medium                        Yes
# 3                  Low              Medium                        Yes
# 4               Medium              Medium                        Yes
#
#   Motivation_Level Internet_Access Family_Income Teacher_Quality School_Type  \
# 0              Low             Yes           Low          Medium      Public
# 1              Low             Yes        Medium          Medium      Public
# 2           Medium             Yes        Medium          Medium      Public
# 3           Medium             Yes        Medium          Medium      Public
# 4           Medium             Yes        Medium            High      Public
#
#   Peer_Influence Learning_Disabilities Parental_Education_Level  \
# ...

# %% [markdown]
# ## Perform the univariate analysis on numerical Columns

# %%
df_num.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#       dtype='object')

# %% [markdown]
# ### Hours_Studied

# %%
# Show the Min

df_num.Hours_Studied.min()
# Out:
# 1

# %%
# Show the Max

df_num.Hours_Studied.max()
# Out:
# 44

# %%
# Show the Mean

df_num.Hours_Studied.mean().round(3)
# Out:
# 19.97

# %%
# Show the plot

df_num.Hours_Studied.plot(kind = "kde", color='#80B3FF')
plt.title("Hours Studied Distribution")
plt.xlabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
#   **Interpretation**
#  - The minimum number of hours studied by a student is 1
#  - The maximum number of hours studied by a student is 44
#  - The average number of hours studied by a student is 19.97
#  - The data is perfectly distributed

# %%
# Show the Numerical Columns

df_num.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#       dtype='object')

# %% [markdown]
# ### Attendance

# %%
# Show the Min

df_num.Attendance.min()
# Out:
# 60

# %%
# Show the Max

df_num.Attendance.max()
# Out:
# 100

# %%
# Show the Mean

df_num.Attendance.mean().round(3)
# Out:
# 80.003

# %%
# plot the graph

df_num.Attendance.plot(kind = "kde", color='#80B3FF')
plt.title("Attendance Distribution")
plt.xlabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The minimum attendance of a student is 60.
#  - The maximum attendance of a student is 100.
#  - The average attendance of a student is 80.003.

# %%
# Show the numerical Columns

df_num.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#       dtype='object')

# %% [markdown]
# ### Sleep_Hours

# %%
# Show the Min

df_num.Sleep_Hours.min()
# Out:
# 4

# %%
# show the Max

df_num.Sleep_Hours.max()
# Out:
# 10

# %%
# Show the Mean

df_num.Sleep_Hours.mean().round(3)
# Out:
# 7.027

# %%
# Plot the graph

df_num.Sleep_Hours.plot(kind = "kde", color='#80B3FF')
plt.title("Sleep Hours Distribution")
plt.xlabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The minimum sleep hours of a student is 4.
#  - The maximum sleep hours of a student is 10.
#  - The average sleep hours of a student is 7.027.
#  - The data follows multi-model distribution.

# %%
# Show the Numerical Columns

df_num.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#       dtype='object')

# %% [markdown]
# ### Previous_Scores

# %%
# Show the Min

df_num.Previous_Scores.min()
# Out:
# 50

# %%
# Show the Max

df_num.Previous_Scores.max()
# Out:
# 100

# %%
# Show the Mean

df_num.Previous_Scores.mean().round(3)
# Out:
# 75.058

# %%
# Plot the Graph

df_num.Previous_Scores.plot(kind = "kde", color='#80B3FF')
plt.title("Previous Scores Distribution")
plt.xlabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The minimum previous score of a student is 50.
#  - The maximum previous score of a student is 100.
#  - The average previous score of a student is 75.058.

# %%
# Show the numerical Columns

df_num.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#       dtype='object')

# %% [markdown]
# ### Tutoring_Sessions

# %%
# Show the Min

df_num.Tutoring_Sessions.min()
# Out:
# 0

# %%
# Show the Max

df_num.Tutoring_Sessions.max()
# Out:
# 8

# %%
# Show the Mean

df_num.Tutoring_Sessions.mean().round(3)
# Out:
# 1.845

# %%
# Plot the Graph

df_num.Tutoring_Sessions.plot(kind = "kde", color='#80B3FF')
plt.title("Tutoring Sessions Distribution")
plt.xlabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The minimum tutoring sessions of a student is 0.
#  - The maximum tutoring sessions of a student is 8.
#  - The average tutoring sessions of a student is 1.845.
#  - The data follows multi model distribution.

# %%
# Show the Numerical Columns

df_num.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#       dtype='object')

# %% [markdown]
# ### Physical_Activity

# %%
# Show the Min

df_num.Physical_Activity.min()
# Out:
# 0

# %%
# Show the Max

df_num.Physical_Activity.max()
# Out:
# 6

# %%
# Show the Mean

df_num.Physical_Activity.mean().round(3)
# Out:
# 2.968

# %%
# Plot the graph

df_num.Physical_Activity.plot(kind = "kde", color='#80B3FF')
plt.title("Physical Activity Distribution")
plt.xlabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The minimum physical activities of a student is 0.
#  - The maximum physical activities of a student is 6.
#  - The average physical activities of a student is 2.968.
#  - The data follows multi model distribution.

# %%
# Show the Numerical columns

df_num.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#       dtype='object')

# %% [markdown]
# ### Exam_Score

# %%
# Show the Min

df_num.Exam_Score.min()
# Out:
# 55

# %%
# Show the Max

df_num.Exam_Score.max()
# Out:
# 101

# %%
# Show the Mean

df_num.Exam_Score.mean().round(3)
# Out:
# 67.245

# %%
# Plot the graph

df_num.Exam_Score.plot(kind = "kde", color='#80B3FF')
plt.title("Exam Score Distribution")
plt.xlabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The minimum exam score of a student is 55.
#  - The maximum exam score of a student is 101.
#  - The average exam score of a student is 67.245.
#  - The data follows normal distribution.

# %% [markdown]
# ## Categorical Columns

# %%
# Show the Categorical Columns

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Parental_Involvement

# %%
# Show the counts

df_cat.Parental_Involvement.value_counts()
# Out:
# Parental_Involvement
# Medium    61301
# High      34605
# Low       24519
# Name: count, dtype: int64

# %%
# Plot the Graph

df_cat.Parental_Involvement.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title(" Count of Parental Involvement")
plt.xlabel("Parental Involvement")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students with medium parental involvement is 61,301.
#  - The number of students with high parental involvement is 34,605.
#  - The number of students with low parental involvement is 24,519.

# %%
# Show the Categorical Columns

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Access_to_Resources

# %%
# Show the Counts

df_cat.Access_to_Resources.value_counts()
# Out:
# Access_to_Resources
# Medium    60450
# High      36143
# Low       23832
# Name: count, dtype: int64

# %%
# plot the graph

df_cat.Access_to_Resources.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of Access to Resources")
plt.xlabel("Access to Resources")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students with medium access to resources is 60,450.
#  - The number of students with high access to resources is 36,143.
#  - The number of students with low access to resources is 23,832.

# %%
# Show the Categorical Column

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Extracurricular_Activities

# %%
# Show the Counts

df_cat.Extracurricular_Activities.value_counts()
# Out:
# Extracurricular_Activities
# Yes    71787
# No     48638
# Name: count, dtype: int64

# %%
# Plot the Graph

df_cat.Extracurricular_Activities.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of Extracurricular Activities")
plt.xlabel("Extracurricular Activities")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students participating in extracurricular activities is 71,787.
#  - The number of students not participating in extracurricular activities is 48,638.

# %%
# Show the Categorical Data

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Motivation_Level

# %%
# Show the Count

df_cat.Motivation_Level.value_counts()
# Out:
# Motivation_Level
# Medium    61101
# Low       35420
# High      23904
# Name: count, dtype: int64

# %%
# Plot the Graph

df_cat.Motivation_Level.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of Motivation Level")
plt.xlabel("Motivation Level")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students with medium motivation level is 61,101.
#  - The number of students with low motivation level is 35,420.
#  - The number of students with high motivation level is 23,904.

# %%
# Show the Categorical Columns

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Internet_Access

# %%
# Show the Counts

df_cat.Internet_Access.value_counts()
# Out:
# Internet_Access
# Yes    111166
# No       9259
# Name: count, dtype: int64

# %%
# Plot the Graph

df_cat.Internet_Access.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of Internet Access")
plt.xlabel("Internet Access")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students with internet access is 111,166.
#  - The number of students without internet access is 9,259.

# %%
# Show the Categorical Columns

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Family_Income

# %%
# Show the Counts

df_cat.Family_Income.value_counts()
# Out:
# Family_Income
# Low       48826
# Medium    48456
# High      23143
# Name: count, dtype: int64

# %%
# Plot the Graph

df_cat.Family_Income.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of Family Income")
plt.xlabel("Family Income")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students with low family income is 48,826.
#  - The number of students with medium family income is 48,456.
#  - The number of students with high family income is 23,143.

# %%
# Show the Categorical Columns

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Teacher_Quality

# %%
# Show the Counts

df_cat.Teacher_Quality.value_counts()
# Out:
# Teacher_Quality
# Medium    72304
# High      35847
# Low       12274
# Name: count, dtype: int64

# %%
# plot the Graph

df_cat.Teacher_Quality.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of Teacher Quality")
plt.xlabel("Teacher Quality")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students with medium teacher quality is 72,304.
#  - The number of students with high teacher quality is 35,847.
#  - The number of students with low teacher quality is 12,274.

# %%
# Show the Categorical Columns

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### School_Type

# %%
# Show the Counts

df_cat.School_Type.value_counts()
# Out:
# School_Type
# Public     83780
# Private    36645
# Name: count, dtype: int64

# %%
# Plot the Graph

df_cat.School_Type.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of School Type")
plt.xlabel("School Type")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students in public schools is 83,780.
#  - The number of students in private schools is 36,645.

# %%
# Show the Categorical Columns

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Peer_Influence

# %%
# Show the Counts

df_cat.Peer_Influence.value_counts()
# Out:
# Peer_Influence
# Positive    48182
# Neutral     47259
# Negative    24984
# Name: count, dtype: int64

# %%
# Plot the Graph

df_cat.Peer_Influence.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of Peer Influence")
plt.xlabel("Peer Influence")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students with positive peer influence is 48,182.
#  - The number of students with neutral peer influence is 47,259.
#  - The number of students with negative peer influence is 24,984.

# %%
# Show the Categorical Columns

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Learning_Disabilities

# %%
# Show the Counts

df_cat.Learning_Disabilities.value_counts()
# Out:
# Learning_Disabilities
# No     107566
# Yes     12859
# Name: count, dtype: int64

# %%
# Plot the Graph

df_cat.Learning_Disabilities.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of Learning Disabilities")
plt.xlabel("Learning Disabilities")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students without learning disabilities is 107,566.
#  - The number of students with learning disabilities is 12,859.

# %%
# Show the Categorical Columns

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Parental_Education_Level

# %%
# Show the Counts

df_cat.Parental_Education_Level.value_counts()
# Out:
# Parental_Education_Level
# High School     59425
# College         36782
# Postgraduate    24218
# Name: count, dtype: int64

# %%
# Plot the Graph

df_cat.Parental_Education_Level.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of Parental Education Level")
plt.xlabel("Parental Education Level")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students whose parents have a high school education is 59,425.
#  - The number of students whose parents have a college education is 36,782.
#  - The number of students whose parents have a postgraduate education is 24,218.

# %%
# Show the Categorical Columns

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Distance_from_Home

# %%
# SHOW THE Counts

df_cat.Distance_from_Home.value_counts()
# Out:
# Distance_from_Home
# Near        71641
# Moderate    36867
# Far         11917
# Name: count, dtype: int64

# %%
  # Plot the Graph

df_cat.Distance_from_Home.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of Distance from Home")
plt.xlabel("Distance from Home")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of students living near the school is 71,641.
#  - The number of students living a moderate distance from the school is 36,867.
#  - The number of students living far from the school is 11,917.

# %%
# Show the categorical Columns

df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %% [markdown]
# ### Gender

# %%
# Show the counts

df_cat.Gender.value_counts()
# Out:
# Gender
# Male      69648
# Female    50777
# Name: count, dtype: int64

# %%
# Plot the Graph

df_cat.Gender.value_counts().plot(kind = "bar", color='#80B3FF', rot=0)
plt.title("Count of Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of male students is 69,648.
#  - The number of female students is 50,777.

# %% [markdown]
# # Bivariate Analysis

# %%
# Show the Correlation Table between categrorical columns and numerical columns

df_num.corr()
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Hours_Studied           1.000000   -0.004235     0.007721         0.022161
# Attendance             -0.004235    1.000000    -0.013017        -0.011328
# Sleep_Hours             0.007721   -0.013017     1.000000        -0.016657
# Previous_Scores         0.022161   -0.011328    -0.016657         1.000000
# Tutoring_Sessions      -0.006359    0.006641    -0.007251        -0.003584
# Physical_Activity       0.003620   -0.012264    -0.000867        -0.000987
# Exam_Score              0.376586    0.510426    -0.008826         0.153530
#
#                    Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied              -0.006359           0.003620    0.376586
# Attendance                  0.006641          -0.012264    0.510426
# Sleep_Hours                -0.007251          -0.000867   -0.008826
# Previous_Scores            -0.003584          -0.000987    0.153530
# ...

# %%
# plot the scater plot between Exam_score and Attendance

sns.scatterplot(x="Exam_Score", y="Attendance", data=df_num)
plt.title("Exam Score vs Attendance")
plt.xlabel("Exam Score")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
# ### Bivariate analysis on 1 numerica snd 1 catagrical columns

# %%
df_cat.columns
# Out:
# Index(['Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender'],
#       dtype='object')

# %%
df_num.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#       dtype='object')

# %% [markdown]
# Parental_Involvemen
#
# Access_to_Resources
#
# Extracurricular_Activities
#
# Motivation_Level
#
# Internet_Access
#
# Family_Income
#
# Teacher_Quality
#
# School_Type
#
# Peer_Influence
#
# Learning_Disabilities
#
# Parental_Education_Level
#
# Distance_from_Home
#
# Gender

# %% [markdown]
# Parental_Involvemen, Hours_Studied
#
# Access_to_Resources, Hours_Studied
#
# Extracurricular_Activities, Hours_Studied
#
# Motivation_Level, Hours_Studied
#
# Internet_Access, Hours_Studied
#
# Family_Income, Hours_Studied
#
# Teacher_Quality, Hours_Studied
#
# School_Type, Hours_Studied
#
# Peer_Influence, Hours_Studied
#
# Learning_Disabilities, Hours_Studied
#
# Parental_Education_Level, Hours_Studied
#
# Distance_from_Home, Hours_Studied
#
# Gender, Hours_Studied

# %%
sns.barplot(x="Parental_Involvement", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Involvement vs Hours Studied")
plt.xlabel("Parental Involvement")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar study hours across different levels of parental involvement.
#  - The average hours studied for all three categories (Low, Medium, High) remain around 20 hours, indicating that parental involvement has little to no effect on study duration.

# %%
# Access_to_Resources, Hours_Studied

sns.barplot(x="Access_to_Resources", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Access to Resources vs Hours Studied")
plt.xlabel("Access to Resources")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar study hours across different levels of access to resources.
#  - The average hours studied for students with High, Medium, and Low access to resources remain around 20 hours, indicating that resource availability does not significantly affect study duration.

# %%
# Extracurricular_Activities, Hours_Studied

sns.barplot(x="Extracurricular_Activities", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Extracurricular Activities vs Hours Studied")
plt.xlabel("Extracurricular Activities")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The distribution of hours studied appears to be nearly identical for both groups.
#  - There is no significant variation in study hours between students involved in extracurricular activities and those who are not.

# %%
# Motivation_Level, Hours_Studied

sns.barplot(x="Motivation_Level", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Motivation Level vs Hours Studied")
plt.xlabel("Motivation Level")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The study hours distribution remains consistent across different motivation levels.
#  - This suggests that motivation level does not have a clear impact on the amount of time spent studying.

# %%
# Internet_Access, Hours_Studied

sns.barplot(x="Internet_Access", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Internet Access vs Hours Studied")
plt.xlabel("Internet Access")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The distribution of hours studied appears to be nearly identical for students with and without internet access.
#  - There is no significant variation in study hours based on internet access, suggesting that having or lacking internet does not strongly impact study duration.

# %%
# Family_Income, Hours_Studied

sns.barplot(x="Family_Income", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Family Income vs Hours Studied")
plt.xlabel("Family Income")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The distribution of hours studied is consistent across all family income levels.
#  - There is no noticeable difference in study hours among students from low, medium, or high-income families, indicating that family income does not significantly affect study time.

# %%
# Teacher_Quality, Hours_Studied

sns.barplot(x="Teacher_Quality", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Teacher Quality vs Hours Studied")
plt.xlabel("Teacher Quality")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The distribution of hours studied appears to be uniform across different teacher quality levels.
#  - There is no significant variation in study hours based on teacher quality, suggesting that students maintain consistent study habits regardless of teacher quality.

# %%
# School_Type, Hours_Studied

sns.barplot(x="School_Type", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("School Type vs Hours Studied")
plt.xlabel("School Type")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The distribution of hours studied is similar for both public and private school students.
#  - There is no noticeable difference in study hours between students from public and private schools, indicating that school type does not significantly impact study time.

# %%
sns.barplot(x="Peer_Influence", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Peer Influence vs Hours Studied")
plt.xlabel("Peer Influence")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The distribution of hours studied is similar across all types of peer influence (positive, negative, and neutral).
#  - Peer influence does not seem to have a notable effect on the number of hours studied.

# %%
sns.barplot(x="Learning_Disabilities", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Learning Disabilities vs Hours Studied")
plt.xlabel("Learning Disabilities")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The distribution of study hours is nearly identical for students with and without learning disabilities.
#  - Having a learning disability does not appear to significantly impact study hours.

# %%
sns.barplot(x="Parental_Education_Level", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Education Level vs Hours Studied")
plt.xlabel("Parental Education Level")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The distribution of hours studied appears to be nearly identical across different parental education levels (High School, College, Postgraduate).
#  - There is no significant variation, suggesting that parental education level does not strongly impact the hours studied by students.

# %%
sns.barplot(x="Distance_from_Home", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Distance from Home vs Hours Studied")
plt.xlabel("Distance from Home")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The hours studied remain almost the same across different distances (Near, Moderate, Far).
#  - There is no clear trend indicating that distance from home affects study hours significantly.

# %%
sns.barplot(x="Gender", y="Hours_Studied", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Gender vs Hours Studied")
plt.xlabel("Gender")
plt.ylabel("Hours Studied")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The hours studied are nearly identical for both male and female students.
#  - There is no noticeable difference in study time based on gender.

# %% [markdown]
# Parental_Involvemen, Attendance
#
# Access_to_Resources, Attendance
#
# Extracurricular_Activities, Attendance
#
# Motivation_Level, Attendance
#
# Internet_Access, Attendance
#
# Family_Income, Attendance
#
# Teacher_Quality, Attendance
#
# School_Type, Attendance
#
# Peer_Influence, Attendance
#
# Learning_Disabilities, Attendance
#
# Parental_Education_Level, Attendance
#
# Distance_from_Home, Attendance
#
# Gender, Attendance

# %%
sns.barplot(x="Parental_Involvement", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Involvement vs Attendance")
plt.xlabel("Parental Involvement")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of parental involvement (Low, Medium, High).
#  - There is no observable impact of parental involvement on attendance.

# %%
sns.barplot(x="Access_to_Resources", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Access to Resources vs Attendance")
plt.xlabel("Access to Resources")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of Access to resources.
#  - There is no observable impact of access to resources on attendance.

# %%
sns.barplot(x="Extracurricular_Activities", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Extracurricular Activities vs Attendance")
plt.xlabel("Extracurricular Activities")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of Extracurricular Activities.
#  - There is no observable impact of Extracurricular Activities on attendance.

# %%
sns.barplot(x="Motivation_Level", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Motivation Level vs Attendance")
plt.xlabel("Motivation Level")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of motivation.
#  - There is no observable impact of motivation level on attendance.

# %%
sns.barplot(x="Internet_Access", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Internet Access vs Attendance")
plt.xlabel("Internet Access")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of internet access.
#  - There is no observable impact of internet access on attendance.

# %%
sns.barplot(x="Family_Income", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Family Income vs Attendance")
plt.xlabel("Family Income")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of family income.
#  - There is no observable impact of family income on attendance.

# %%
sns.barplot(x="Teacher_Quality", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Teacher Quality vs Attendance")
plt.xlabel("Teacher Quality")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of teacher quality.
#  - There is no observable impact of teacher quality on attendance.

# %%
sns.barplot(x="School_Type", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("School Type vs Attendance")
plt.xlabel("School Type")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of school type.
#  - There is no observable impact of school type on attendance.

# %%
sns.barplot(x="Peer_Influence", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Peer Influence vs Attendance")
plt.xlabel("Peer Influence")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of peer influence.
#  - There is no observable impact of peer influence on attendance.

# %%
sns.barplot(x="Learning_Disabilities", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Learning Disabilities vs Attendance")
plt.xlabel("Learning Disabilities")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of learning disabilities.
#  - There is no observable impact of learning disability on attendance.

# %%
sns.barplot(x="Parental_Education_Level", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Education Level vs Attendance")
plt.xlabel("Parental Education Level")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of parental education.
#  - There is no observable impact of parental education on attendance.

# %%
sns.barplot(x="Distance_from_Home", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Distance from Home vs Attendance")
plt.xlabel("Distance from Home")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of distance from home.
#  - There is no observable impact of distance from home on attendance.

# %%
sns.barplot(x="Gender", y="Attendance", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Gender vs Attendance")
plt.xlabel("Gender")
plt.ylabel("Attendance")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Attendance levels remain constant across different levels of gender.
#  - There is no observable impact of gender on attendance.

# %% [markdown]
# Parental_Involvemen, Sleep_Hours
#
# Access_to_Resources, Sleep_Hours
#
# Extracurricular_Activities, Sleep_Hours
#
# Motivation_Level, Sleep_Hours
#
# Internet_Access, Sleep_Hours
#
# Family_Income, Sleep_Hours
#
# Teacher_Quality, Sleep_Hours
#
# School_Type, Sleep_Hours
#
# Peer_Influence, Sleep_Hours
#
# Learning_Disabilities, Sleep_Hours
#
# Parental_Education_Level, Sleep_Hours
#
# Distance_from_Home, Sleep_Hours
#
# Gender, Sleep_Hours

# %%
sns.barplot(x="Parental_Involvement", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Involvement vs Sleep Hours")
plt.xlabel("Parental Involvement")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of parental involvement.
#  - There is no observable impact of parental involvement on sleep hours.

# %%
sns.barplot(x="Access_to_Resources", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Access to Resources vs Sleep Hours")
plt.xlabel("Access to Resources")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of access to resource.
#  - There is no observable impact of access to resource on sleep hours.

# %%
sns.barplot(x="Extracurricular_Activities", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Extracurricular Activities vs Sleep Hours")
plt.xlabel("Extracurricular Activities")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of extracurricular activities.
#  - There is no observable impact of extracurricular activities on sleep hours.

# %%
sns.barplot(x="Motivation_Level", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Motivation Level vs Sleep Hours")
plt.xlabel("Motivation Level")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of motivation level.
#  - There is no observable impact of motivation level on sleep hours.

# %%
sns.barplot(x="Internet_Access", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Internet Access vs Sleep Hours")
plt.xlabel("Internet Access")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of internet access.
#  - There is no observable impact of internet access on sleep hours.

# %%
sns.barplot(x="Family_Income", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Family Income vs Sleep Hours")
plt.xlabel("Family Income")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of family income.
#  - There is no observable impact of family income on sleep hours.

# %%
sns.barplot(x="Teacher_Quality", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Teacher Quality vs Sleep Hours")
plt.xlabel("Teacher Quality")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of teacher quality.
#  - There is no observable impact of teacher quality on sleep hours.

# %%
sns.barplot(x="School_Type", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("School Type vs Sleep Hours")
plt.xlabel("School Type")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of school type.
#  - There is no observable impact of school type on sleep hours.

# %%
sns.barplot(x="Peer_Influence", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Peer Influence vs Sleep Hours")
plt.xlabel("Peer Influence")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of peer influence.
#  - There is no observable impact of peer influence on sleep hours.

# %%
sns.barplot(x="Learning_Disabilities", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Learning Disabilities vs Sleep Hours")
plt.xlabel("Learning Disabilities")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of learning disabilities.
#  - There is no observable impact of learning disabilities on sleep hours.

# %%
sns.barplot(x="Parental_Education_Level", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Education Level vs Sleep Hours")
plt.xlabel("Parental Education Level")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of parental education.
#  - There is no observable impact of parental education on sleep hours.

# %%
sns.barplot(x="Distance_from_Home", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Distance from Home vs Sleep Hours")
plt.xlabel("Distance from Home")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of distance from home.
#  - There is no observable impact of distance from home on sleep hours.

# %%
sns.barplot(x="Gender", y="Sleep_Hours", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Gender vs Sleep Hours")
plt.xlabel("Gender")
plt.ylabel("Sleep Hours")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Sleep hours remain constant across different levels of gender.
#  - There is no observable impact of gender on sleep hours.

# %% [markdown]
# Parental_Involvemen, Previous_Scores
#
# Access_to_Resources, Previous_Scores
#
# Extracurricular_Activities, Previous_Scores
#
# Motivation_Level, Previous_Scores
#
# Internet_Access, Previous_Scores
#
# Family_Income, Previous_Scores
#
# Teacher_Quality, Previous_Scores
#
# School_Type, Previous_Scores
#
# Peer_Influence, Previous_Scores
#
# Learning_Disabilities, Previous_Scores
#
# Parental_Education_Level, Previous_Scores
#
# Distance_from_Home, Previous_Scores
#
# Gender, Previous_Scores

# %%
sns.barplot(x="Parental_Involvement", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Involvement vs Previous Scores")
plt.xlabel("Parental Involvement")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of parental involvement.
#  - There is no observable impact of parental involvement on previous score.

# %%
sns.barplot(x="Access_to_Resources", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Access to Resources vs Previous Scores")
plt.xlabel("Access to Resources")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of access to resources.
#  - There is no observable impact of access to resources on previous score.

# %%
sns.barplot(x="Extracurricular_Activities", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Extracurricular Activities vs Previous Scores")
plt.xlabel("Extracurricular Activities")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of extracurricular acitivities.
#  - There is no observable impact of extracurricular activities on previous score.

# %%
sns.barplot(x="Motivation_Level", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Motivation Level vs Previous Scores")
plt.xlabel("Motivation Level")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of motivation level.
#  - There is no observable impact of motivation level on previous score.

# %%
sns.barplot(x="Internet_Access", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Internet Access vs Previous Scores")
plt.xlabel("Internet Access")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of internet access.
#  - There is no observable impact of internet access on previous score.

# %%
sns.barplot(x="Family_Income", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Family Income vs Previous Scores")
plt.xlabel("Family Income")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of family income.
#  - There is no observable impact of family income on previous score.

# %%
sns.barplot(x="Teacher_Quality", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Teacher Quality vs Previous Scores")
plt.xlabel("Teacher Quality")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of teacher quality.
#  - There is no observable impact of teacher quality on previous score.

# %%
sns.barplot(x="School_Type", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("School Type vs Previous Scores")
plt.xlabel("School Type")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of school type.
#  - There is no observable impact of school type on previous score.

# %%
sns.barplot(x="Peer_Influence", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Peer Influence vs Previous Scores")
plt.xlabel("Peer Influence")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of peer influence.
#  - There is no observable impact of peer influence on previous score.

# %%
sns.barplot(x="Learning_Disabilities", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Learning Disabilities vs Previous Scores")
plt.xlabel("Learning Disabilities")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of learning disabilities.
#  - There is no observable impact of learning disabilities on previous score.

# %%
sns.barplot(x="Parental_Education_Level", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Education Level vs Previous Scores")
plt.xlabel("Parental Education Level")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of parental education.
#  - There is no observable impact of parental education on previous score.

# %%
sns.barplot(x="Distance_from_Home", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Distance from Home vs Previous Scores")
plt.xlabel("Distance from Home")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score  remain constant across different levels of distance from home.
#  - There is no observable impact of distance from home on previous score.

# %%
sns.barplot(x="Gender", y="Previous_Scores", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Gender vs Previous Scores")
plt.xlabel("Gender")
plt.ylabel("Previous Scores")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Previous score remain constant across different levels of gender.
#  - There is no observable impact of gender on previous score.

# %% [markdown]
# Parental_Involvemen, Tutoring_Sessions
#
# Access_to_Resources, Tutoring_Sessions
#
# Extracurricular_Activities, Tutoring_Sessions
#
# Motivation_Level, Tutoring_Sessions
#
# Internet_Access, Tutoring_Sessions
#
# Family_Income, Tutoring_Sessions
#
# Teacher_Quality, Tutoring_Sessions
#
# School_Type, Tutoring_Sessions
#
# Peer_Influence, Tutoring_Sessions
#
# Learning_Disabilities, Tutoring_Sessions
#
# Parental_Education_Level, Tutoring_Sessions
#
# Distance_from_Home, Tutoring_Sessions
#
# Gender, Tutoring_Sessions

# %%
sns.barplot(x="Parental_Involvement", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Involvement vs Tutoring Sessions")
plt.xlabel("Parental Involvement")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of parental involvement.
#  - There is no observable impact of parental involvement on tutoring sessions.

# %%
sns.barplot(x="Access_to_Resources", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Access to Resources vs Tutoring Sessions")
plt.xlabel("Access to Resources")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of access to resource.
#  - There is no observable impact of access to resource on tutoring sessions.

# %%
sns.barplot(x="Extracurricular_Activities", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Extracurricular Activities vs Tutoring Sessions")
plt.xlabel("Extracurricular Activities")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of extracurricular activities.
#  - There is no observable impact of extracurricular activities on tutoring sessions.

# %%
sns.barplot(x="Motivation_Level", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Motivation Level vs Tutoring Sessions")
plt.xlabel("Motivation Level")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of motivation.
#  - There is no observable impact of motivation level on tutoring sessions.

# %%
sns.barplot(x="Internet_Access", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Internet Access vs Tutoring Sessions")
plt.xlabel("Internet Access")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of internet access.
#  - There is no observable impact of internet access on tutoring sessions.

# %%
sns.barplot(x="Family_Income", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Family Income vs Tutoring Sessions")
plt.xlabel("Family Income")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of family income.
#  - There is no observable impact of family income on tutoring sessions.

# %%
sns.barplot(x="Teacher_Quality", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Teacher Quality vs Tutoring Sessions")
plt.xlabel("Teacher Quality")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of teacher quality.
#  - There is no observable impact of teacher quality on tutoring sessions.

# %%
sns.barplot(x="School_Type", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("School Type vs Tutoring Sessions")
plt.xlabel("School Type")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of school type.
#  - There is no observable impact of school type on tutoring sessions.

# %%
sns.barplot(x="Peer_Influence", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Peer Influence vs Tutoring Sessions")
plt.xlabel("Peer Influence")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of peer influence.
#  - There is no observable impact of peer incluence on tutoring sessions.

# %%
sns.barplot(x="Learning_Disabilities", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Learning Disabilities vs Tutoring Sessions")
plt.xlabel("Learning Disabilities")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of learning disabilities.
#  - There is no observable impact of learning disabilities on tutoring sessions.

# %%
sns.barplot(x="Parental_Education_Level", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Education Level vs Tutoring Sessions")
plt.xlabel("Parental Education Level")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of parental education.
#  - There is no observable impact of parental education on tutoring sessions.

# %%
sns.barplot(x="Distance_from_Home", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Distance from Home vs Tutoring Sessions")
plt.xlabel("Distance from Home")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of distance from home.
#  - There is no observable impact of distance from home on tutoring sessions.

# %%
sns.barplot(x="Gender", y="Tutoring_Sessions", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Gender vs Tutoring Sessions")
plt.xlabel("Gender")
plt.ylabel("Tutoring Sessions")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Tutoring sessions remain constant across different levels of gender.
#  - There is no observable impact of gender on tutoring sessions.

# %% [markdown]
# Parental_Involvemen, Physical_Activity
#
# Access_to_Resources, Physical_Activity
#
# Extracurricular_Activities, Physical_Activity
#
# Motivation_Level, Physical_Activity
#
# Internet_Access, Physical_Activity
#
# Family_Income, Physical_Activity
#
# Teacher_Quality, Physical_Activity
#
# School_Type, Physical_Activity
#
# Peer_Influence, Physical_Activity
#
# Learning_Disabilities, Physical_Activity
#
# Parental_Education_Level, Physical_Activity
#
# Distance_from_Home, Physical_Activity
#
# Gender, Physical_Activity

# %%
sns.barplot(x="Parental_Involvement", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Involvement vs Physical Activity")
plt.xlabel("Parental Involvement")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of parental involvement.
#  - There is no observable impact of parental involvement on physical activities.

# %%
sns.barplot(x="Access_to_Resources", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Access to Resources vs Physical Activity")
plt.xlabel("Access to Resources")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of access to resource.
#  - There is no observable impact of access to resource on physical activities.

# %%
sns.barplot(x="Extracurricular_Activities", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Extracurricular Activities vs Physical Activity")
plt.xlabel("Extracurricular Activities")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of extracurricular activities.
#  - There is no observable impact of extracurricular activities on physical activities.

# %%
sns.barplot(x="Motivation_Level", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Motivation Level vs Physical Activity")
plt.xlabel("Motivation Level")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of motivation level.
#  - There is no observable impact of motivation level on physical activities.

# %%
sns.barplot(x="Internet_Access", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Internet Access vs Physical Activity")
plt.xlabel("Internet Access")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of internet access.
#  - There is no observable impact of internet access on physical activities.

# %%
sns.barplot(x="Family_Income", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Family Income vs Physical Activity")
plt.xlabel("Family Income")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of family income.
#  - There is no observable impact of family income on physical activities.

# %%
sns.barplot(x="Teacher_Quality", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Teacher Quality vs Physical Activity")
plt.xlabel("Teacher Quality")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of teacher quality.
#  - There is no observable impact of teacher quality on physical activities.

# %%
sns.barplot(x="School_Type", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("School Type vs Physical Activity")
plt.xlabel("School Type")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of school type.
#  - There is no observable impact of school type on physical activities.

# %%
sns.barplot(x="Peer_Influence", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Peer Influence vs Physical Activity")
plt.xlabel("Peer Influence")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of peer influence.
#  - There is no observable impact of peer influence on physical activities.

# %%
sns.barplot(x="Learning_Disabilities", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Learning Disabilities vs Physical Activity")
plt.xlabel("Learning Disabilities")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of learning disabilities.
#  - There is no observable impact of learning disabilities on physical activities.

# %%
sns.barplot(x="Parental_Education_Level", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Education Level vs Physical Activity")
plt.xlabel("Parental Education Level")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of parental education.
#  - There is no observable impact of parental education on physical activities.

# %%
sns.barplot(x="Distance_from_Home", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Distance from Home vs Physical Activity")
plt.xlabel("Distance from Home")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of distance from home.
#  - There is no observable impact of distance from home on physical activities.

# %%
sns.barplot(x="Gender", y="Physical_Activity", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Gender vs Physical Activity")
plt.xlabel("Gender")
plt.ylabel("Physical Activity")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Physical activities remain constant across different levels of gender.
#  - There is no observable impact of gender on physical activities.

# %% [markdown]
# Parental_Involvemen, Exam_Score
#
# Access_to_Resources, Exam_Score
#
# Extracurricular_Activities, Exam_Score
#
# Motivation_Level, Exam_Score
#
# Internet_Access, Exam_Score
#
# Family_Income, Exam_Score
#
# Teacher_Quality, Exam_Score
#
# School_Type, Exam_Score
#
# Peer_Influence, Exam_Score
#
# Learning_Disabilities, Exam_Score
#
# Parental_Education_Level, Exam_Score
#
# Distance_from_Home, Exam_Score
#
# Gender, Exam_Score

# %%
sns.barplot(x="Parental_Involvement", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Involvement vs Exam Score")
plt.xlabel("Parental Involvement")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of parental involvement.
#  - There is no observable impact of parental involvement on exam score.

# %%
sns.barplot(x="Access_to_Resources", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Access to Resources vs Exam Score")
plt.xlabel("Access to Resources")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of access to resource.
#  - There is no observable impact of access to resource on exam score.

# %%
sns.barplot(x="Extracurricular_Activities", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Extracurricular Activities vs Exam Score")
plt.xlabel("Extracurricular Activities")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of extracurricular activities.
#  - There is no observable impact of extracurricular activities on exam score.

# %%
sns.barplot(x="Motivation_Level", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Motivation Level vs Exam Score")
plt.xlabel("Motivation Level")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of motivation.
#  - There is no observable impact of motivation level on exam score.

# %%
sns.barplot(x="Internet_Access", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Internet Access vs Exam Score")
plt.xlabel("Internet Access")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of internet access.
#  - There is no observable impact of internet access on exam score.

# %%
sns.barplot(x="Family_Income", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Family Income vs Exam Score")
plt.xlabel("Family Income")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of family income.
#  - There is no observable impact of family income on exam score.

# %%
sns.barplot(x="Teacher_Quality", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Teacher Quality vs Exam Score")
plt.xlabel("Teacher Quality")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of teacher quality.
#  - There is no observable impact of teacher quality on exam score.

# %%
sns.barplot(x="School_Type", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("School Type vs Exam Score")
plt.xlabel("School Type")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of school type.
#  - There is no observable impact of school type on exam score.

# %%
sns.barplot(x="Peer_Influence", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Peer Influence vs Exam Score")
plt.xlabel("Peer Influence")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of peer influence.
#  - There is no observable impact of peer influence on exam score.

# %%
sns.barplot(x="Learning_Disabilities", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Learning Disabilities vs Exam Score")
plt.xlabel("Learning Disabilities")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of learning disabilities.
#  - There is no observable impact of learning disabilities on exam score.

# %%
sns.barplot(x="Parental_Education_Level", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Parental Education Level vs Exam Score")
plt.xlabel("Parental Education Level")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of parental education.
#  - There is no observable impact of parental education on exam score.

# %%
sns.barplot(x="Distance_from_Home", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Distance from Home vs Exam Score")
plt.xlabel("Distance from Home")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of distance from home.
#  - There is no observable impact of distance from home on exam score.

# %%
sns.barplot(x="Gender", y="Exam_Score", data=df_student, color='#80B3FF', estimator='mean')
plt.title("Gender vs Exam Score")
plt.xlabel("Gender")
plt.ylabel("Exam Score")
plt.grid()
plt.show()

# %% [markdown]
#  **Interpretation**
#  - Exam score remain constant across different levels of gender.
#  - There is no observable impact of gender on exam score.

# %% [markdown]
# # Summary of Analysis on Student Performance Factors
# **1. Data Overview**
#  - The dataset consists of 124,694 observations (rows) and 20 attributes (columns).
#
#  - 7 numerical and 13 categorical columns are present.
#
#  - Some missing data is detected and addressed during preprocessing.
#
#  - No significant outliers were found in the dataset.
#
# **2. Data Preprocessing & Univariate Analysis**
#  - **Hours Studied:**
#
#  - Students studied between 1 and 44 hours, with an average of 19.97 hours.
#
#  - The distribution appears normal without anomalies.
#
#  - **Attendance:**
#
#  - The minimum attendance recorded is 60%, while the maximum is 100%.
#
#  - The average attendance across students is 83.49%, indicating most students maintain a decent attendance record.
#
# **3. Bivariate Analysis & Correlations**
#
#  - A positive correlation exists between hours studied and student performance, suggesting higher study time improves grades.
#
#  - **Attendance vs. Performance:**
#
#  - Students with higher attendance percentages tend to perform better.
#
#  - **Parental Education Impact:**
#
#  - Higher parental education levels show a correlation with better student academic performance.
#
#  - **Extracurricular Activities:**
#
#  - Students involved in extracurriculars show mixed performance outcomes, suggesting a balance between academics and activities is key.
#
# **4. Key Insights**
#
#  - Study Hours & Attendance are strong indicators of academic success.
#
#  - Parental education & support significantly impact student performance.
#
#  - Extracurricular activities need to be balanced to avoid negatively affecting study hours.
#
#  - No extreme data anomalies were found, making the dataset reliable for analysis.
#
# **5. Conclusion**
#
#  - The analysis provides actionable insights for educators, students, and policymakers. Encouraging a balance between study time, attendance, and extracurricular engagement can significantly enhance student performance. Addressing socio-economic disparities and parental involvement can also contribute to better academic outcomes.
